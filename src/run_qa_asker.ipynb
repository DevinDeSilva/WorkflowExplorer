# %%
import os
import sys
import dycomutils as common_utils

from LLMQA import question_asker_and_loger
sys.path.append(".")
# Out:
# 11/23/2025 20:24:29 - INFO - src.explorer_updates -   Loading .env file from: /home/desild/work/research/chatbs/v2/.env
# 11/23/2025 20:24:29 - INFO - src.explorer_updates -   Loading config: /home/desild/work/research/chatbs/v2/prov.config.yaml
# 11/23/2025 20:24:29 - INFO - src.explorer_updates -   Loading metadata: /home/desild/work/research/chatbs/v2/data/workflow/50_sample_graph/chatbs_sample_metadata.json
# 11/23/2025 20:24:29 - INFO - src.explorer_updates -   Initializing GraphManager...
# 11/23/2025 20:24:30 - INFO - src.explorer_updates -   Graph loaded with 24073 triples.
# 11/23/2025 20:24:30 - INFO - LLMQA -   Loading .env file from: /home/desild/work/research/chatbs/v2/.env
# 11/23/2025 20:24:30 - INFO - LLMQA -   Loading config: /home/desild/work/research/chatbs/v2/prov.config.yaml
# 11/23/2025 20:24:30 - INFO - LLMQA -   Loading metadata: /home/desild/work/research/chatbs/v2/data/workflow/chatbs_sample_metadata.json
# ...

# %%
EXPERIEMNT_ID = "LLM_QA_TEST_01"

# %%
gt = common_utils.serialization.load_json(os.path.join("evalutions", "GT", "questions_results.json"))

# %%
question_asker_and_loger("what are the programs generated by AI?", "Individual_Testing")
# Out:
# 11/23/2025 22:23:16 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:23:16 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# ['provone:Program', 'eo:AITask']
# 11/23/2025 22:23:19 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:23:20 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:23:20 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# 11/23/2025 22:23:21 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:23:21 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# ...

# %%
question_asker_and_loger("How many overall steps in this pipeline?", "Individual_Testing")
# Out:
# 11/23/2025 22:25:03 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:25:03 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# ['provone:Execution', 'provone:Program', 'provone:Channel']
# 11/23/2025 22:25:07 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:25:09 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 22:25:09 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# 11/23/2025 22:25:09 - ERROR - LLMQA -   Error executing step plan1: 'sub-question'
# 11/23/2025 22:25:10 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
# for _, v in gt.items():
#     question_asker_and_loger(v['question'], EXPERIEMNT_ID)
# Out:
# 11/23/2025 20:24:32 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 20:24:32 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# ['provone:Data', 'provone:Execution', 'provone:Program']
# 11/23/2025 20:24:37 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 20:24:40 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11/23/2025 20:24:40 - WARNING - LLMQA -   Error parsing JSON (layer 1): Expecting value: line 1 column 1 (char 0). Trying to extract from markdown.
# 11/23/2025 20:24:40 - ERROR - LLMQA -   Error executing step plan1: 'sub-question'
# 11/23/2025 20:24:41 - INFO - httpx -   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
